# %% [markdown]
# ### Introduction to Grok AI API InteractionThis notebook demonstrates how to interact with the Grok AI API using Python. You will learn how to authenticate with the API, send a query, and handle the response.

# %%
# Input your API keyapi_key = input("Enter your Grok AI API key: ")

# %% [markdown]
# ### Define the QuerySpecify the query or data you want to send to the Grok AI API.

# %%
# Define the queryquery = "What is the capital of France?"

# %% [markdown]
# ### Function to Make the API RequestThe function below sends a query to the Grok AI API and retrieves the response. Ensure the API endpoint is correctly configured.

# %%
import requests

def make_request(api_key, query):
    """
    Make a simple request to the Grok AI API.

    Parameters:
        api_key (str): Your Grok AI API key.
        query (str): The query or data you want to send to the API.

    Returns:
        dict: The API response.
    """
    # Define the API endpoint
    api_endpoint = "<API_ENDPOINT>"

    # Set up the request headers
    headers = {
        "Authorization": f"Bearer {api_key}",
        "Content-Type": "application/json"
    }

    # Set up the payload
    payload = {
        "query": query
    }

    # Make the POST request
    response = requests.post(api_endpoint, headers=headers, json=payload)

    # Check if the response is successful
    if response.status_code == 200:
        return response.json()
    else:
        return {"error": f"Request failed with status code {response.status_code}", "details": response.text}

# %% [markdown]
# ### Make the RequestCall the `make_request` function with the API key and query to retrieve a response from the Grok AI API.

# %%
# Make the request
response = make_request(api_key, query)

# Display the response
print("Response from Grok AI API:")
print(response)
